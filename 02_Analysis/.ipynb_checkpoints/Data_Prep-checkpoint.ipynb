# %%
import pandas as pd
import re
import statsmodels.formula.api as smf  
import matplotlib.pyplot as plt
import numpy as np

high_valence_results = pd.read_excel("./Song Reaction Survey A (Responses).xlsx") 
low_valence_results = pd.read_excel("./Song Reaction Survey B (Responses).xlsx")
high_valence_results = high_valence_results.rename(columns={"Timestamp": "Time",
"Age (As a number)": "Age", 
"Music Preference\n(Select which genres you listen to or enjoy)": "Music_Preference",
"Current Mood\n(Describe your mood right now on a scale of 1-10 with 1 being saddest and 10 being happiest)": "Initial_Mood",
"Pick ONLY one of the songs at random by clicking a link\nPlease do NOT change your selection after clicking the link. Also, it does not matter which song you pick just please make sure you indicate which song you selected.": "Track_Link",
"Describe your mood right now(after listening to the song) on a scale of 1-10 with 1 being saddest and 10 being happiest": "Final_Mood",
"Did you like the song?": "Liked_Song",
"Have you heard this song before?": "Heard_Before",
"Additional Thoughts\n(If there is anything else you would like to add write it here)": "Additional_Thoughts"})
low_valence_results = low_valence_results.rename(columns={"Timestamp": "Time",
"Age (As a number)": "Age", 
"Music Preference\n(Select which genres you listen to or enjoy)": "Music_Preference",
"Current Mood\n(Describe your mood right now on a scale of 1-10 with 1 being saddest and 10 being happiest)": "Initial_Mood",
"Pick ONLY one of the songs at random by clicking a link\nPlease do NOT change your selection after clicking the link. Also, it does not matter which song you pick just please make sure you indicate which song you selected.": "Track_Link",
"Describe your mood right now on a scale of 1-10 (after listening to the song) with 1 being saddest and 10 being happiest": "Final_Mood",
"Did you like the song?": "Liked_Song",
"Have you heard this song before?": "Heard_Before",
"Additional Thoughts\n(If there is anything else you would like to add write it here)": "Additional_Thoughts"})
results = pd.concat([high_valence_results,low_valence_results], axis=0, ignore_index=True)
results
# Out:
#                       Time  Age  Gender  \
# 0  2024-12-30 23:44:39.830   17  Female
# 1  2024-12-31 01:05:50.260   17    Male
# 2  2024-12-31 20:43:59.040   17    Male
# 3  2024-12-31 20:44:08.844   18    Male
# 4  2025-01-03 18:38:37.981   17    Male
# 5  2025-01-05 20:01:57.996   17    Male
# 6  2025-01-05 20:13:59.991   17  Female
# 7  2025-01-06 11:03:53.057   17    Male
# 8  2025-01-06 22:11:23.983   17  Female
# 9  2025-01-07 05:08:16.241   17  Female
# 10 2025-01-07 12:02:35.608   17    Male
# 11 2025-01-07 12:41:32.108   17    Male
# 12 2025-01-07 12:41:36.440   17    Male
# 13 2025-01-07 13:34:03.938   15    Male
# 14 2025-01-07 16:30:24.307   18    Male
# 15 2024-12-31 00:13:15.674   17    Male
# 16 2024-12-31 01:32:08.067   17    Male
# 17 2024-12-31 09:36:32.279   18    Male
# 18 2024-12-31 11:52:28.751   17    Male
# 19 2025-01-01 01:19:48.518   17    Male
# 20 2025-01-04 22:00:36.381   17    Male
# 21 2025-01-05 18:22:28.603   17    Male
# 22 2025-01-05 19:01:37.503   17  Female
# 23 2025-01-05 20:10:53.343   17    Male
# 24 2025-01-06 09:48:20.841   17  Female
# 25 2025-01-06 17:39:49.936   18    Male
# 26 2025-01-06 20:56:32.968   17    Male
https://open.spotify.com/track/2dLLR6qlu5UJ5gk...           9           6
# 28  https://open.spotify.com/track/7I20yqgoGEEfXBK...           8           8
# 29  https://open.spotify.com/track/3eJyXwiYepWvEDK...           8           8
#
#    Heard_Before                                Additional_Thoughts  delta
# 0            No                                                 No      0
# 1            No           now thats a jam! 🎶🎶🎶🎶🎶🎶🎶🎶 d-_-b 🎶🎶🎶🎶🎶🎶🎶🎶      2
# 2            No  It wasn’t Kanye west (ALDI) Reilly said it’s m...     -2
# 3            No                                          Hey Oli 😎      0
# 4            No                                                NaN      0
# 5            No                                 was lowk reptitive      1
# 6            No                                                NaN     -1
# 7            No  I think the song was more nuetral calm song wh...      0
# 8            No                                                  W      1
# 9            No                    did colin recommend these songs      1
# 10          Yes                                       I own u you      -2
# 11           No                                 it was pretty good     -1
# 12           No                                          good song      0
# 13           No  Very groovy song and relaxing too, but a littl...      1
# 14           No                                                  .     -2
# 15           No  I randomly chose the “life is” link. It was ok...      1
# 16           No  Good song, gave me bjork instrumental vibes at...      0
# 17           No                                      Very angelic       0
# 18           No                                                 na     -2
# 19           No  The song was kind of melancholic, but I though...      1
# 20           No                              Bro is fantanomaxxing     -1
# 21          Yes                                                 No      1
# 22           No  My mood is significantly calmer after listenin...     -1
# 23          Yes                                                NaN      1
# 24           No                                                NaN      0
# 25          Yes                                                 no      0
# 26          Yes                                        decent song     -1
# 27          Yes                                                 hi      1
# 28           No   it made me much more calm, and gets you in yo...      1
# 29          Yes                                          Good song      1

# %%
high_valence_songs = pd.read_csv("./pop42A.csv")
low_valence_songs = pd.read_csv("./pop42B.csv")
songs = pd.concat([high_valence_songs, low_valence_songs], axis=0, ignore_index=True)

# %%
results = pd.DataFrame(results)

def combineData(row):
    link = row["Track_Link"]
    link = link.split("/")[-1]
    uri = link.split("?")[0]
    return re.sub(r'^(.*)', r'spotify:track:\1',uri)

results["track_uri"] = results.apply(combineData, axis=1)
results

#results.columns
# Out:
#                       Time  Age  Gender  \
# 0  2024-12-30 23:44:39.830   17  Female
# 1  2024-12-31 01:05:50.260   17    Male
# 2  2024-12-31 20:43:59.040   17    Male
# 3  2024-12-31 20:44:08.844   18    Male
# 4  2025-01-03 18:38:37.981   17    Male
# 5  2025-01-05 20:01:57.996   17    Male
# 6  2025-01-05 20:13:59.991   17  Female
# 7  2025-01-06 11:03:53.057   17    Male
# 8  2025-01-06 22:11:23.983   17  Female
# 9  2025-01-07 05:08:16.241   17  Female
# 10 2025-01-07 12:02:35.608   17    Male
# 11 2025-01-07 12:41:32.108   17    Male
# 12 2025-01-07 12:41:36.440   17    Male
# 13 2025-01-07 13:34:03.938   15    Male
# 14 2025-01-07 16:30:24.307   18    Male
# 15 2024-12-31 00:13:15.674   17    Male
# 16 2024-12-31 01:32:08.067   17    Male
# 17 2024-12-31 09:36:32.279   18    Male
# 18 2024-12-31 11:52:28.751   17    Male
# 19 2025-01-01 01:19:48.518   17    Male
# 20 2025-01-04 22:00:36.381   17    Male
# 21 2025-01-05 18:22:28.603   17    Male
# 22 2025-01-05 19:01:37.503   17  Female
# 23 2025-01-05 20:10:53.343   17    Male
# 24 2025-01-06 09:48:20.841   17  Female
# 25 2025-01-06 17:39:49.936   18    Male
# 26 2025-01-06 20:56:32.968   17    Male
# 27 2025-01-06 23:09:32.517   17  Female
# 28 2025-01-07 11:30:15.106   17    Male
# 29 2025-01-07 15:41:31.969   14    Male
#
#                                   Music_Preference  Initial_Mood  \
# 0                          Pop, Hip Hop/Rap, Other             5
# 1                                      Hip Hop/Rap             6
# 2                                 Pop, Hip Hop/Rap             8
# 3                         Rock, Hip Hop/Rap, Other             8
# 4                      Pop, Hip Hop/Rap, Classical             3
# 5                      Pop, Hip Hop/Rap, Classical             8
# 6                                              Pop             6
# 7                Pop, Hip Hop/Rap, Classical, Jazz             6
# 8         Pop, Hip Hop/Rap, Classical, Jazz, Other             5
# 9                           Pop, Rock, Hip Hop/Rap             8
# 10                                Pop, Hip Hop/Rap            10
# 11  Pop, Rock, Hip Hop/Rap, Classical, Jazz, Other            10
# 12              Rock, Hip Hop/Rap, Classical, Jazz            10
# 13                               Rock, Hip Hop/Rap             6
# 14                              Hip Hop/Rap, Other             6
# 15  Pop, Rock, Hip Hop/Rap, Classical, Jazz, Other             5
# 16                     Pop, Rock, Classical, Other             7
# 17                          Pop, Hip Hop/Rap, Jazz             7
# 18                                  Pop, Classical             8
# 19                                       Pop, Rock             8
# 20                          Pop, Rock, Hip Hop/Rap             4
# 21                                     Hip Hop/Rap             6
# 22        Pop, Hip Hop/Rap, Classical, Jazz, Other             7
# 23  Pop, Rock, Hip Hop/Rap, Classical, Jazz, Other             4
# 24                                Pop, Hip Hop/Rap             8
# 25                              Hip Hop/Rap, Other             6
# 26                                Pop, Hip Hop/Rap             7
# 27                                Pop, Hip Hop/Rap             8
# 28                          Pop, Rock, Hip Hop/Rap             7
# 29                          Pop, Rock, Hip Hop/Rap             7
#
#                                            Track_Link  Final_Mood  Liked_Song  \
# 0   https://open.spotify.com/track/0Ensfv1iBDcsOF6...           5           7
# 1   https://open.spotify.com/track/5uTjNzGKCQ50syn...           8           8
# 2   https://open.spotify.com/track/0Ensfv1iBDcsOF6...           6           6
# 3   https://open.spotify.com/track/5uTjNzGKCQ50syn...           8           4
# 4   https://open.spotify.com/track/0Ensfv1iBDcsOF6...           3           5
# 5   https://open.spotify.com/track/5uTjNzGKCQ50syn...           9           6
# 6   https://open.spotify.com/track/7wXJyWtRktzx7sh...           5           5
# 7   https://open.spotify.com/track/0Ensfv1iBDcsOF6...           6           5
# 8   https://open.spotify.com/track/5uTjNzGKCQ50syn...           6           6
# 9   https://open.spotify.com/track/0Ensfv1iBDcsOF6...           9           8
# 10  https://open.spotify.com/track/7wXJyWtRktzx7sh...           8           6
# 11  https://open.spotify.com/track/5uTjNzGKCQ50syn...           9           6
# 12  https://open.spotify.com/track/7wXJyWtRktzx7sh...          10           7
# 13  https://open.spotify.com/track/0Ensfv1iBDcsOF6...           7           6
# 14  https://open.spotify.com/track/7F1xUyDoz9vSbwS...           4           2
# 15  https://open.spotify.com/track/7I20yqgoGEEfXBK...           6           5
# 16  https://open.spotify.com/track/7I20yqgoGEEfXBK...           7           8
# 17  https://open.spotify.com/track/1vgSaC0BPlL6LEm...           7           5
# 18  https://open.spotify.com/track/3eJyXwiYepWvEDK...           6           4
# 19  https://open.spotify.com/track/7I20yqgoGEEfXBK...           9           8
# 20  https://open.spotify.com/track/7JKW0gH84HWAyDE...           3           5
# 21  https://open.spotify.com/track/7I20yqgoGEEfXBK...           7           7
# 22  https://open.spotify.com/track/7I20yqgoGEEfXBK...           6           8
# 23  https://open.spotify.com/track/2dLLR6qlu5UJ5gk...
# 21  spotify:track:7I20yqgoGEEfXBK8YNICJ8
# 22  spotify:track:7I20yqgoGEEfXBK8YNICJ8
# 23  spotify:track:2dLLR6qlu5UJ5gk0dKz0h3
# 24  spotify:track:7JKW0gH84HWAyDEBQgsNbX
# 25  spotify:track:2dLLR6qlu5UJ5gk0dKz0h3
# 26  spotify:track:2dLLR6qlu5UJ5gk0dKz0h3
# 27  spotify:track:2dLLR6qlu5UJ5gk0dKz0h3
# 28  spotify:track:7I20yqgoGEEfXBK8YNICJ8
# 29  spotify:track:3eJyXwiYepWvEDKABhm7lL

# %%
finalData = pd.merge(results, songs, how="left", left_on = "track_uri", right_on= "track_uri", indicator=True)
finalData

# %% [markdown]
# # Modeling/Regression

# %%
m = smf.ols("delta ~ valence", finalData).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  delta   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.041
# Method:                 Least Squares   F-statistic:                   0.02268
# Date:                Fri, 31 Jan 2025   Prob (F-statistic):              0.882
# Time:                        23:57:37   Log-Likelihood:                -39.964
# No. Observations:                  26   AIC:                             83.93
# Df Residuals:                      24   BIC:                             86.44
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0297      0.507      0.058      0.954      -1.018       1.077
# valence       -0.1226      0.814     -0.151      0.882      -1.803       1.558
# ==============================================================================
# Omnibus:                        1.806   Durbin-Watson:                   2.705
# Prob(Omnibus):                  0.405   Jarque-Bera (JB):                1.422
# Skew:                          -0.393   Prob(JB):                        0.491
# Kurtosis:                       2.166   Cond. No.                         4.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Plotting the relationship between 'age' and 'eval'    
plt.figure(figsize=(10, 6))    
plt.scatter(finalData['valence'], finalData['delta'], alpha=0.7, label='Data Points')    
    
# Calculate and plot a polynomial (quadratic) trend line    
p = np.poly1d(np.polyfit(finalData['valence'], finalData['delta'], 1))    
ages = np.linspace(finalData['valence'].min(), finalData['valence'].max(), 100)    
plt.plot(ages, p(ages), color='red', label='Quadratic Trend Line')    
    
# Customize plot    
plt.title('Relationship between Valence and Mood')    
plt.xlabel('Valence')    
plt.ylabel('Delta in Mood')    
plt.legend()    
plt.grid(True)    
plt.show()

# %%
m2 = smf.ols("delta ~ valence + Initial_Mood", finalData).fit()
m2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  delta   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                 -0.024
# Method:                 Least Squares   F-statistic:                    0.7099
# Date:                Fri, 31 Jan 2025   Prob (F-statistic):              0.502
# Time:                        23:57:42   Log-Likelihood:                -39.198
# No. Observations:                  26   AIC:                             84.40
# Df Residuals:                      23   BIC:                             88.17
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        1.0622      1.008      1.053      0.303      -1.024       3.148
# valence         -0.0281      0.812     -0.035      0.973      -1.707       1.651
# Initial_Mood    -0.1576      0.133     -1.182      0.249      -0.433       0.118
# ==============================================================================
# Omnibus:                        2.515   Durbin-Watson:                   2.912
# Prob(Omnibus):                  0.284   Jarque-Bera (JB):                1.581
# Skew:                          -0.356   Prob(JB):                        0.454
# Kurtosis:                       2.023   Cond. No.                         34.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Calculate the mean of 'age'  
valence_mean = finalData['valence'].mean()  
initial_mood_mean = finalData['Initial_Mood'].mean()  
liked_song_mean = finalData['Liked_Song'].mean()
  
# Center the 'age' variable  
finalData['valence_centered'] = finalData['valence'] - valence_mean  
finalData['initial_mood_centered'] = finalData['Initial_Mood'] - initial_mood_mean  
finalData['liked_song_centered'] = finalData['Liked_Song'] - liked_song_mean

# %%
m2 = smf.ols("delta ~ valence_centered + initial_mood_centered", finalData).fit()
m2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  delta   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                 -0.024
# Method:                 Least Squares   F-statistic:                    0.7099
# Date:                Fri, 31 Jan 2025   Prob (F-statistic):              0.502
# Time:                        23:57:59   Log-Likelihood:                -39.198
# No. Observations:                  26   AIC:                             84.40
# Df Residuals:                      23   BIC:                             88.17
# Df Model:                           2
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.0385      0.228     -0.169      0.867      -0.510       0.433
# valence_centered         -0.0281      0.812     -0.035      0.973      -1.707       1.651
# initial_mood_centered    -0.1576      0.133     -1.182      0.249      -0.433       0.118
# ==============================================================================
# Omnibus:                        2.515   Durbin-Watson:                   2.912
# Prob(Omnibus):                  0.284   Jarque-Bera (JB):                1.581
# Skew:                          -0.356   Prob(JB):                        0.454
# Kurtosis:                       2.023   Cond. No.                         6.12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
m3 = smf.ols("delta ~ valence_centered + initial_mood_centered + liked_song_centered", finalData).fit()
m3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  delta   R-squared:                       0.432
# Model:                            OLS   Adj. R-squared:                  0.355
# Method:                 Least Squares   F-statistic:                     5.585
# Date:                Fri, 31 Jan 2025   Prob (F-statistic):            0.00528
# Time:                        23:58:02   Log-Likelihood:                -32.615
# No. Observations:                  26   AIC:                             73.23
# Df Residuals:                      22   BIC:                             78.26
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.0385      0.181     -0.213      0.834      -0.414       0.337
# valence_centered          0.4607      0.657      0.701      0.490      -0.902       1.823
# initial_mood_centered    -0.2537      0.109     -2.332      0.029      -0.479      -0.028
# liked_song_centered       0.4676      0.123      3.808      0.001       0.213       0.722
# ==============================================================================
# Omnibus:                        1.680   Durbin-Watson:                   3.137
# Prob(Omnibus):                  0.432   Jarque-Bera (JB):                1.398
# Skew:                          -0.409   Prob(JB):                        0.497
# Kurtosis:                       2.212   Cond. No.                         6.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
m4 = smf.ols("delta ~ valence_centered + initial_mood_centered + liked_song_centered + C(Heard_Before)", finalData).fit()
m4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  delta   R-squared:                       0.434
# Model:                            OLS   Adj. R-squared:                  0.326
# Method:                 Least Squares   F-statistic:                     4.019
# Date:                Fri, 31 Jan 2025   Prob (F-statistic):             0.0142
# Time:                        23:58:06   Log-Likelihood:                -32.586
# No. Observations:                  26   AIC:                             75.17
# Df Residuals:                      21   BIC:                             81.46
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -0.0235      0.197     -0.119      0.906      -0.434       0.387
# C(Heard_Before)[T.Yes]    -0.1298      0.601     -0.216      0.831      -1.380       1.120
# valence_centered           0.4408      0.678      0.650      0.523      -0.969       1.850
# initial_mood_centered     -0.2502      0.112     -2.224      0.037      -0.484      -0.016
# liked_song_centered        0.4715      0.127      3.717      0.001       0.208       0.735
# ==============================================================================
# Omnibus:                        1.673   Durbin-Watson:                   3.153
# Prob(Omnibus):                  0.433   Jarque-Bera (JB):                1.408
# Skew:                          -0.418   Prob(JB):                        0.495
# Kurtosis:                       2.224   Cond. No.                         6.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Interpretation
